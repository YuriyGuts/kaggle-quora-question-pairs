# %%
import sklearn_evaluation as skeval

# %%
search_result = load('/home/yuriyguts/Projects/kaggle-quora-question-pairs/data/aux/xgboost-gridsearch-fine-legacy.pickle')

# %%
skeval.plot.grid_search(
    search_result,
    change='colsample_bytree',
    kind='bar'
)

# %%
skeval.plot.grid_search(
    search_result,
    change=['colsample_bytree', 'subsample'],
    subset={
        'num_boost_round': 500,
        'learning_rate': 0.05,
        'max_depth': 10,
    }
)
